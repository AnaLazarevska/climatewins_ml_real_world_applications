# %% [markdown]
# # 2.3 Complex Machine Learning Models and Keras Part 2 - Maastricht

# %% [markdown]
# ## Contents:
#
# 1. Import Libraries
# 2. Import Datasets
# 3. Data Wrangling
# 4. Reshaping the Model
# 5. Data Split
# 6. Random Forest Model
# 7. Features Importance

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn import datasets  
from sklearn.ensemble import RandomForestClassifier
from numpy import argmax
from sklearn import metrics  
from sklearn.tree import plot_tree
from sklearn import tree
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2. Import Datasets

# %%
# Define path to dataset
path = r'/Users/analazarevska/Documents/CAREER FOUNDRY/Data Analytics Program/Machine Learning/A1, Basics of Machine Learning for Analysts/ClimateWins/'

# Import dataset
df = pd.read_csv(os.path.join(path, 'Data Sets', 'df_cleaned_with_date.csv'))
df_pleasant = pd.read_csv(os.path.join(path, 'Data Sets', 'df_pleasant_with_date.csv'))

# %%
df.shape
# Out:
# (22950, 137)

# %%
df_pleasant.shape
# Out:
# (22950, 16)

# %% [markdown]
# ## 3. Data Wrangling

# %%
# Filter the data for Maastricht
list_maastricht = list(x for x in df.columns if x.find('MAASTRICHT') >=0)

# Create a dataframe with those columns
df_maastricht = df[list_maastricht]
df_maastricht
# Out:
#        MAASTRICHT_cloud_cover  MAASTRICHT_humidity  MAASTRICHT_pressure  \
# 0                           7                 0.83               1.0063
# 1                           8                 0.92               1.0062
# 2                           7                 0.97               1.0167
# 3                           7                 0.89               1.0277
# 4                           7                 0.92               1.0259
# ...                       ...                  ...                  ...
# 22945                       8                 0.67               1.0201
# 22946                       7                 0.70               1.0190
# 22947                       8                 0.69               1.0183
# 22948                       8                 0.73               1.0181
# 22949                       8                 0.80               1.0160
#
#        MAASTRICHT_global_radiation  MAASTRICHT_precipitation  \
# ...

# %%
# Filter data for Maastricht in df_pleasant
pleasant_list_maastricht = df_pleasant['MAASTRICHT_pleasant_weather']
pleasant_list_maastricht
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 22945    0
# 22946    0
# 22947    0
# 22948    0
# 22949    0
# Name: MAASTRICHT_pleasant_weather, Length: 22950, dtype: int64

# %%
df_maastricht.shape
# Out:
# (22950, 9)

# %%
pleasant_list_maastricht.shape
# Out:
# (22950,)

# %% [markdown]
# ## 4. Reshaping the Model

# %%
X = df_maastricht

# %%
y = pleasant_list_maastricht

# %%
# Turn X and y from a df to arrays
X = np.array(X)
y = np.array(y)

# %%
X.shape
# Out:
# (22950, 9)

# %%
y.shape
# Out:
# (22950,)

# %% [markdown]
# ## 5. Data Split

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 42)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (17212, 9) (17212,)
# (5738, 9) (5738,)

# %% [markdown]
# ## 6. Random Forest Model

# %%
# Create a RF classifier
clf = RandomForestClassifier(n_estimators = 100)#, max_depth=5)  
  
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Perform predictions on the test dataset
y_pred = clf.predict(X_test)
  
# Use metrics module for accuracy calculation
print("Model Accuracy: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# Model Accuracy:  1.0

# %%
# Class-names = {0:'Unpleasant Weather', 1:'Pleasant Weather'}
fig = plt.figure(figsize=(80,40))
plot_tree(clf.estimators_[15], fontsize = 20, filled=True);

# %%
fig.savefig(os.path.join(path, 'Visualisations', 'random_forest_Maastricht.png'))

# %% [markdown]
# ## 7. Features Importance

# %%
# Retrieve feature importances from the trained model
newarray = clf.feature_importances_
print(clf.feature_importances_.shape)
newarray
# Out:
# (9,)
# array([0.03006401, 0.01925144, 0.01094818, 0.08198227, 0.31953498,
#        0.08743552, 0.17007566, 0.03633087, 0.24437708])

# %%
# Create a list of weather features
wx_list = [feature.replace('MAASTRICHT_', '') for feature in list_maastricht]
wx_list
# Out:
# ['cloud_cover',
#  'humidity',
#  'pressure',
#  'global_radiation',
#  'precipitation',
#  'sunshine',
#  'temp_mean',
#  'temp_min',
#  'temp_max']

# %%
important = pd.Series(newarray, index = wx_list)
important
# Out:
# cloud_cover         0.030064
# humidity            0.019251
# pressure            0.010948
# global_radiation    0.081982
# precipitation       0.319535
# sunshine            0.087436
# temp_mean           0.170076
# temp_min            0.036331
# temp_max            0.244377
# dtype: float64

# %%
# Plot the results
# %matplotlib inline

plt.style.use('fivethirtyeight')
# list of x locations for plotting
x_values = list(range(len(newarray)))
print(wx_list)

plt.bar(x_values, newarray, orientation = 'vertical')
plt.xticks(x_values, wx_list, rotation='vertical')
plt.ylabel('Importance'); plt.xlabel('Feature'); plt.title('Features Importances for Maastricht (all years)');

plt.savefig(os.path.join(path, 'Visualisations', 'Maastricht_feature_importances.png'), bbox_inches='tight')
plt.show()
# Out:
# ['cloud_cover', 'humidity', 'pressure', 'global_radiation', 'precipitation', 'sunshine', 'temp_mean', 'temp_min', 'temp_max']
